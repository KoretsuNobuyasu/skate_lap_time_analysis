# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import sys
import importlib as imp
import os.path
import gc
from IPython.display import Image

path = Path(os.path.dirname(os.path.abspath("__file__"))).parent
PROJ_ROOT = str(path) + "/dev/projects/shuppin/work"
sys.path = list(set(sys.path))
sys.path.append(r'{}/lib'.format(PROJ_ROOT))
sys.path.append(r'{}/lib/cplot'.format(PROJ_ROOT))


PROJ_ROOT
sys.path
# Out:
# ['/opt/conda/lib/python3.7',
#  '',
#  '/home/jovyan/.ipython',
#  '/home/jovyan/work',
#  '/opt/conda/lib/python3.7/lib-dynload',
#  '/opt/conda/lib/python3.7/site-packages/IPython/extensions',
#  '/opt/conda/lib/python37.zip',
#  '/opt/conda/lib/python3.7/site-packages',
#  '/Applications/PyCharm 2020.1 EAP.app/Contents/plugins/python/helpers-pro/jupyter_debug',
#  '/Applications/PyCharm 2020.1 EAP.app/Contents/plugins/python/helpers/pydev',
#  '/home/jovyan/dev/projects/shuppin/work/lib',
#  '/home/jovyan/dev/projects/shuppin/work/lib/cplot']

# %% [markdown]
# # Plot Colors
# ```
# color_list = {
#     0: '#4A7BD6', # han blue
#     1: '#D64A4A', # english vermilion
#     2: '#4AD669', # ufo green
#     3: '#D6CA4A', # max green yellow
#     4: '#B84DD6', # majorette blue
#     5: '#FF8D59', # coral
#     6: '#5D4AD6', # iris
#     7: '#7C4A2B', # russet
#     8: '#D64AD1', # steal pink
#     9: '#4AC3D6', # sea serpent
#   }
# ```

# %%
Image(filename=PROJ_ROOT+'/notebooks/images/image-20200305114918818.png')

# %%
Image(filename=PROJ_ROOT+'/notebooks/images/image-20200305115057538.png')
